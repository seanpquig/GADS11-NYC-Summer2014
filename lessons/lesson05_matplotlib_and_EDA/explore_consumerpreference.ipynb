# %% [markdown]
# # Exploratory Data Analysis: Consumer Preference
# A voyage through evaluating preferential factors in cinema using public IMDB data

# %% [markdown]
# _This notebook is adapted from [Chris Beaumont's](http://chrisbeaumont.org/) ["Rubric for Data Wrangling and Exploration"](http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb)_

# %%
# %matplotlib inline
# from pylab import *

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Acquire Data

# %%
# Dump the data into a frame and label it so if we come back to it later we'll know what's what
# We can see that there were no titles so we'll provide them
# Its also clear that there's tab separations 
names = ['imdbID', 'Title', 'year', 'score', 'votes', 'runtime', 'genres']
data = pd.read_csv('imdb_top_10000.txt', delimiter='\t', names=names).dropna()
print "Number of rows: %i. Number of columns: %i" %(data.shape[0],data.shape[1])
data.head()  # print the first 5 rows
# Out:
# Number of rows: 9999. Number of columns: 7
#       imdbID                            Title  year  score   votes    runtime  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994    9.2  619479  142 mins.
# 1  tt0110912              Pulp Fiction (1994)  1994    9.0  490065  154 mins.
# 2  tt0137523                Fight Club (1999)  1999    8.8  458173  139 mins.
# 3  tt0133093                The Matrix (1999)  1999    8.7  448114  136 mins.
# 4  tt1375666                 Inception (2010)  2010    8.9  385149  148 mins.
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Clean Data

# %% [markdown]
# #### MUNGING!!
# Weed to adjust the runtime and genres so we can use them.  And may as well remove the superfluous year from title as well.
#
# You must love to munge, or work with someone who loves to munge, to get anywhere in data science.  Understanding strings are lists, is helpful.

# %%
# Fix the title
data['Title'] = [t[0:-7] for t in data.Title]
data.Title
# Out:
# 0                           The Shawshank Redemption
# 1                                       Pulp Fiction
# 2                                         Fight Club
# 3                                         The Matrix
# 4                                          Inception
# 5                                       Forrest Gump
# 6                                    American Beauty
# 7                                             Avatar
# 8                                   Schindler's List
# 9     Star Wars: Episode V - The Empire Strikes Back
# 10                                     Batman Begins
# 11                                The Usual Suspects
# 12                          The Silence of the Lambs
# 13                                           Titanic
# 14                                        Braveheart
# ...
# 9985              The Dunwich Horror
# 9986                  I Live in Fear
# 9987              The Long Walk Home
# 9988                         Evil Ed
# 9989                     Another You
# 9990                      Zerophilia
# 9991    The Merchant of Four Seasons
# 9992                       Stateside
# 9993                    Scarlet Diva
# 9994                          Aprile
# 9995                         Meduzot
# 9996                  Daltry Calhoun
# 9997          The Quiller Memorandum
# 9998                            Taal
# 9999                  The Navigators
# Name: Title, Length: 9999, dtype: object

# %%
data.year
# Out:
# 0     1994
# 1     1994
# 2     1999
# 3     1999
# 4     2010
# 5     1994
# 6     1999
# 7     2009
# 8     1993
# 9     1980
# 10    2005
# 11    1995
# 12    1991
# 13    1997
# 14    1995
# ...
# 9985    1970
# 9986    1955
# 9987    1990
# 9988    1995
# 9989    1991
# 9990    2005
# 9991    1971
# 9992    2004
# 9993    2000
# 9994    1998
# 9995    2007
# 9996    2005
# 9997    1966
# 9998    1999
# 9999    2001
# Name: year, Length: 9999, dtype: int64

# %%
# Fix the runtime
# For each element of data.runtime, split the string at a space and get the first element as a number.
# We can use a "comprehension":

clean_runtime = [float(r.split(' ')[0]) for r in data.runtime]
data['runtime'] = clean_runtime

# %%
data
# Out:
#        imdbID                                              Title  year  score  \
# 0   tt0111161                           The Shawshank Redemption  1994    9.2
# 1   tt0110912                                       Pulp Fiction  1994    9.0
# 2   tt0137523                                         Fight Club  1999    8.8
# 3   tt0133093                                         The Matrix  1999    8.7
# 4   tt1375666                                          Inception  2010    8.9
# 5   tt0109830                                       Forrest Gump  1994    8.7
# 6   tt0169547                                    American Beauty  1999    8.6
# 7   tt0499549                                             Avatar  2009    8.1
# 8   tt0108052                                   Schindler's List  1993    8.9
# 9   tt0080684     Star Wars: Episode V - The Empire Strikes Back  1980    8.8
# 10  tt0372784                                      Batman Begins  2005    8.3
# 11  tt0114814                                 The Usual Suspects  1995    8.7
# 12  tt0102926                           The Silence of the Lambs  1991    8.7
# 13  tt0120338                                            Titanic  1997    7.4
# 14  tt0112573                                         Braveheart  1995    8.4
# 15  tt0167404                                    The Sixth Sense  1999    8.2
# 16  tt0266697                                  Kill Bill: Vol. 1  2003    8.2
# 17  tt0099685                                         Goodfellas  1990    8.8
# 18  tt0416449                                                300  2006    7.8
# 19  tt0482571                                       The Prestige  2006    8.4
# 20  tt0105236                                     Reservoir Dogs  1992    8.4
# 21  tt0110413                             Leon: The Professional  1994    8.6
# 22  tt0120689                                     The Green Mile  1999    8.4
# 23  tt0361748                               Inglourious Basterds  2009    8.4
# 24  tt0910970                                          WALL\xb7E  2008    8.5
# 25  tt0468569                                    The Dark Knight  2008    8.9
# 26  tt0068646                                      The Godfather  1972    9.2
# 27  tt0120737  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 28  tt0167260      The Lord of the Rings: The Return of the King  2003    8.8
# 29  tt0167261              The Lord of the Rings: The Two Towers  2002    8.7
# 30  tt0076759                 Star Wars: Episode IV - A New Hope  1977    8.8
# 31  tt0114369                                              Se7en  1995    8.7
# 32  tt0172495                                          Gladiator  2000    8.4
# 33  tt0209144                                            Memento  2000    8.7
# 34  tt0120815                                Saving Private Ryan  1998    8.5
# 35  tt0407887                                       The Departed  2006    8.5
# 36  tt0401792                                           Sin City  2005    8.3
# 37  tt0071562                             The Godfather: Part II  1974    9.0
# 38  tt0325980  Pirates of the Caribbean: The Curse of the Bla...  2003    8.0
# 39  tt0103064                         Terminator 2: Judgment Day  1991    8.6
# 40  tt0082971                            Raiders of the Lost Ark  1981    8.7
# 41  tt0434409                                     V for Vendetta  2006    8.2
# 42  tt0120586                                 American History X  1998    8.6
# 43  tt0338013              Eternal Sunshine of the Spotless Mind  2004    8.5
# 44  tt0073486                    One Flew Over the Cuckoo's Nest  1975    8.9
# 45  tt0246578                                       Donnie Darko  2001    8.2
# 46  tt0088763                                 Back to the Future  1985    8.4
# 47  tt0086190         Star Wars: Episode VI - Return of the Jedi  1983    8.3
# 48  tt0477348                             No Country for Old Men  2007    8.2
# 49  tt0418279                                       Transformers  2007    7.2
# 50  tt0066921                                 A Clockwork Orange  1971    8.5
# 51  tt1010048                                Slumdog Millionaire  2008    8.2
# 52  tt0211915                                          Am\xe9lie  2001    8.5
# 53  tt0095016                                           Die Hard  1988    8.3
# 54  tt0088247                                     The Terminator  1984    8.1
# 55  tt0083658                                       Blade Runner  1982    8.3
# 56  tt0208092                                            Snatch.  2000    8.3
# 57  tt0266543                                       Finding Nemo  2003    8.2
# 58  tt0317248                                        City of God  2002    8.8
# 59  tt1136608                                         District 9  2009    8.2
#           ...                                                ...   ...    ...
#
#      votes  runtime                                     genres
# 0   619479      142                                Crime|Drama
# 1   490065      154                             Crime|Thriller
# 2   458173      139                     Drama|Mystery|Thriller
# 3   448114      136                    Action|Adventure|Sci-Fi
# 4   385149      148           Action|Adventure|Sci-Fi|Thriller
# 5   368994      142                       Comedy|Drama|Romance
# 6   338332      122                                      Drama
# 7   336855      162            Action|Adventure|Fantasy|Sci-Fi
# 8   325888      195                Biography|Drama|History|War
# 9   320105      124             Action|Adventure|Family|Sci-Fi
# 10  316613      140                Action|Crime|Drama|Thriller
# 11  306624      106                     Crime|Mystery|Thriller
# 12  293081      118                             Crime|Thriller
# 13  284245      194            Adventure|Drama|History|Romance
# 14  281446      177         Action|Biography|Drama|History|War
# 15  278210      107                     Drama|Mystery|Thriller
# 16  272983      111                      Action|Crime|Thriller
# 17  270728      146             Biography|Crime|Drama|Thriller
# 18  269328      117                 Action|Fantasy|History|War
# 19  258396      130                     Drama|Mystery|Thriller
# 20  247390       99                     Crime|Mystery|Thriller
# 21  244568      110                       Crime|Drama|Thriller
# 22  243660      189                Crime|Drama|Fantasy|Mystery
# 23  240995      153                        Adventure|Drama|War
# 24  229364       98  Animation|Adventure|Family|Romance|Sci-Fi
# 25  555122      152                Action|Crime|Drama|Thriller
# 26  474189      175                                Crime|Drama
# 27  451263      178             Action|Adventure|Drama|Fantasy
# 28  428791      201             Action|Adventure|Drama|Fantasy
# 29  383113      179             Action|Adventure|Drama|Fantasy
# 30  364211      121     Action|Adventure|Family|Fantasy|Sci-Fi
# 31  337198      127               Crime|Drama|Mystery|Thriller
# 32  334107      155                     Action|Adventure|Drama
# 33  325663      113               Crime|Drama|Mystery|Thriller
# 34  317912      169                   Action|Drama|History|War
# 35  315448      151                     Crime|Mystery|Thriller
# 36  295014      124                Action|Crime|Drama|Thriller
# 37  291169      200                                Crime|Drama
# 38  282758      143                   Action|Adventure|Fantasy
# 39  280590      137                     Action|Sci-Fi|Thriller
# 40  277941      115                           Action|Adventure
# 41  272272      132                     Action|Sci-Fi|Thriller
# 42  270082      119                                Crime|Drama
# 43  260298      108                       Drama|Romance|Sci-Fi
# 44  255503      133                                      Drama
# 45  246756      113                       Drama|Mystery|Sci-Fi
# 46  244444      116                    Adventure|Family|Sci-Fi
# 47  242129      134     Action|Adventure|Family|Fantasy|Sci-Fi
# 48  237275      122                       Crime|Drama|Thriller
# 49  229119      144                     Action|Sci-Fi|Thriller
# 50  225495      136                         Crime|Drama|Sci-Fi
# 51  220634      120               Crime|Drama|Romance|Thriller
# 52  215732      122                     Comedy|Fantasy|Romance
# 53  214352      131                            Action|Thriller
# 54  211834      107                              Action|Sci-Fi
# 55  210220      117                      Drama|Sci-Fi|Thriller
# 56  208975      104                             Crime|Thriller
# 57  203841      100          Animation|Adventure|Comedy|Family
# 58  199917      130                                Crime|Drama
# 59  198635      112               Action|Drama|Sci-Fi|Thriller
#        ...      ...                                        ...
#
# [9999 rows x 7 columns]

# %%
# Splitting up the genres
#determine the unique genres
genresset = set()

for m in data.genres:
    genresset.update(g for g in m.split('|'))
genresset = sorted(genresset)

#make a column for each genre
for genre in genresset:
    data[genre] = [genre in movie.split('|') for movie in data.genres]

# %%
data
# Out:
#        imdbID                                              Title  year  score  \
# 0   tt0111161                           The Shawshank Redemption  1994    9.2
# 1   tt0110912                                       Pulp Fiction  1994    9.0
# 2   tt0137523                                         Fight Club  1999    8.8
# 3   tt0133093                                         The Matrix  1999    8.7
# 4   tt1375666                                          Inception  2010    8.9
# 5   tt0109830                                       Forrest Gump  1994    8.7
# 6   tt0169547                                    American Beauty  1999    8.6
# 7   tt0499549                                             Avatar  2009    8.1
# 8   tt0108052                                   Schindler's List  1993    8.9
# 9   tt0080684     Star Wars: Episode V - The Empire Strikes Back  1980    8.8
# 10  tt0372784                                      Batman Begins  2005    8.3
# 11  tt0114814                                 The Usual Suspects  1995    8.7
# 12  tt0102926                           The Silence of the Lambs  1991    8.7
# 13  tt0120338                                            Titanic  1997    7.4
# 14  tt0112573                                         Braveheart  1995    8.4
# 15  tt0167404                                    The Sixth Sense  1999    8.2
# 16  tt0266697                                  Kill Bill: Vol. 1  2003    8.2
# 17  tt0099685                                         Goodfellas  1990    8.8
# 18  tt0416449                                                300  2006    7.8
# 19  tt0482571                                       The Prestige  2006    8.4
# 20  tt0105236                                     Reservoir Dogs  1992    8.4
# 21  tt0110413                             Leon: The Professional  1994    8.6
# 22  tt0120689                                     The Green Mile  1999    8.4
# 23  tt0361748                               Inglourious Basterds  2009    8.4
# 24  tt0910970                                          WALL\xb7E  2008    8.5
# 25  tt0468569                                    The Dark Knight  2008    8.9
# 26  tt0068646                                      The Godfather  1972    9.2
# 27  tt0120737  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 28  tt0167260      The Lord of the Rings: The Return of the King  2003    8.8
# 29  tt0167261              The Lord of the Rings: The Two Towers  2002    8.7
# 30  tt0076759                 Star Wars: Episode IV - A New Hope  1977    8.8
# 31  tt0114369                                              Se7en  1995    8.7
# 32  tt0172495                                          Gladiator  2000    8.4
# 33  tt0209144                                            Memento  2000    8.7
# 34  tt0120815                                Saving Private Ryan  1998    8.5
# 35  tt0407887                                       The Departed  2006    8.5
# 36  tt0401792                                           Sin City  2005    8.3
# 37  tt0071562                             The Godfather: Part II  1974    9.0
# 38  tt0325980  Pirates of the Caribbean: The Curse of the Bla...  2003    8.0
# 39  tt0103064                         Terminator 2: Judgment Day  1991    8.6
# 40  tt0082971                            Raiders of the Lost Ark  1981    8.7
# 41  tt0434409                                     V for Vendetta  2006    8.2
# 42  tt0120586                                 American History X  1998    8.6
# 43  tt0338013              Eternal Sunshine of the Spotless Mind  2004    8.5
# 44  tt0073486                    One Flew Over the Cuckoo's Nest  1975    8.9
# 45  tt0246578                                       Donnie Darko  2001    8.2
# 46  tt0088763                                 Back to the Future  1985    8.4
# 47  tt0086190         Star Wars: Episode VI - Return of the Jedi  1983    8.3
# 48  tt0477348                             No Country for Old Men  2007    8.2
# 49  tt0418279                                       Transformers  2007    7.2
# 50  tt0066921                                 A Clockwork Orange  1971    8.5
# 51  tt1010048                                Slumdog Millionaire  2008    8.2
# 52  tt0211915                                          Am\xe9lie  2001    8.5
# 53  tt0095016                                           Die Hard  1988    8.3
# 54  tt0088247                                     The Terminator  1984    8.1
# 55  tt0083658                                       Blade Runner  1982    8.3
# 56  tt0208092                                            Snatch.  2000    8.3
# 57  tt0266543                                       Finding Nemo  2003    8.2
# 58  tt0317248                                        City of God  2002    8.8
# 59  tt1136608                                         District 9  2009    8.2
#           ...                                                ...   ...    ...
#
#      votes  runtime                                     genres Action  Adult  \
# 0   619479      142                                Crime|Drama  False  False
# 1   490065      154                             Crime|Thriller  False  False
# 2   458173      139                     Drama|Mystery|Thriller  False  False
# 3   448114      136                    Action|Adventure|Sci-Fi   True  False
# 4   385149      148           Action|Adventure|Sci-Fi|Thriller   True  False
# 5   368994      142                       Comedy|Drama|Romance  False  False
# 6   338332      122                                      Drama  False  False
# 7   336855      162            Action|Adventure|Fantasy|Sci-Fi   True  False
# 8   325888      195                Biography|Drama|History|War  False  False
# 9   320105      124             Action|Adventure|Family|Sci-Fi   True  False
# 10  316613      140                Action|Crime|Drama|Thriller   True  False
# 11  306624      106                     Crime|Mystery|Thriller  False  False
# 12  293081      118                             Crime|Thriller  False  False
# 13  284245      194            Adventure|Drama|History|Romance  False  False
# 14  281446      177         Action|Biography|Drama|History|War   True  False
# 15  278210      107                     Drama|Mystery|Thriller  False  False
# 16  272983      111                      Action|Crime|Thriller   True  False
# 17  270728      146             Biography|Crime|Drama|Thriller  False  False
# 18  269328      117                 Action|Fantasy|History|War   True  False
# 19  258396      130                     Drama|Mystery|Thriller  False  False
# 20  247390       99                     Crime|Mystery|Thriller  False  False
# 21  244568      110                       Crime|Drama|Thriller  False  False
# 22  243660      189                Crime|Drama|Fantasy|Mystery  False  False
# 23  240995      153                        Adventure|Drama|War  False  False
# 24  229364       98  Animation|Adventure|Family|Romance|Sci-Fi  False  False
# 25  555122      152                Action|Crime|Drama|Thriller   True  False
# 26  474189      175                                Crime|Drama  False  False
# 27  451263      178             Action|Adventure|Drama|Fantasy   True  False
# 28  428791      201             Action|Adventure|Drama|Fantasy   True  False
# 29  383113      179             Action|Adventure|Drama|Fantasy   True  False
# 30  364211      121     Action|Adventure|Family|Fantasy|Sci-Fi   True  False
# 31  337198      127               Crime|Drama|Mystery|Thriller  False  False
# 32  334107      155                     Action|Adventure|Drama   True  False
# 33  325663      113               Crime|Drama|Mystery|Thriller  False  False
# 34  317912      169                   Action|Drama|History|War   True  False
# 35  315448      151                     Crime|Mystery|Thriller  False  False
# 36  295014      124                Action|Crime|Drama|Thriller   True  False
# 37  291169      200                                Crime|Drama  False  False
# 38  282758      143                   Action|Adventure|Fantasy   True  False
# 39  280590      137                     Action|Sci-Fi|Thriller   True  False
# 40  277941      115                           Action|Adventure   True  False
# 41  272272      132                     Action|Sci-Fi|Thriller   True  False
# 42  270082      119                                Crime|Drama  False  False
# 43  260298      108                       Drama|Romance|Sci-Fi  False  False
# 44  255503      133                                      Drama  False  False
# 45  246756      113                       Drama|Mystery|Sci-Fi  False  False
# 46  244444      116                    Adventure|Family|Sci-Fi  False  False
# 47  242129      134     Action|Adventure|Family|Fantasy|Sci-Fi   True  False
# 48  237275      122                       Crime|Drama|Thriller  False  False
# 49  229119      144                     Action|Sci-Fi|Thriller   True  False
# 50  225495      136                         Crime|Drama|Sci-Fi  False  False
# 51  220634      120               Crime|Drama|Romance|Thriller  False  False
# 52  215732      122                     Comedy|Fantasy|Romance  False  False
# 53  214352      131                            Action|Thriller   True  False
# 54  211834      107                              Action|Sci-Fi   True  False
# 55  210220      117                      Drama|Sci-Fi|Thriller  False  False
# 56  208975      104                             Crime|Thriller  False  False
# 57  203841      100          Animation|Adventure|Comedy|Family  False  False
# 58  199917      130                                Crime|Drama  False  False
# 59  198635      112               Action|Drama|Sci-Fi|Thriller   True  False
#        ...      ...                                        ...    ...    ...
#
#    Adventure Animation Biography Comedy  Crime  Drama Family Fantasy  \
# 0      False     False     False  False   True   True  False   False
# 1      False     False     False  False   True  False  False   False
# 2      False     False     False  False  False   True  False   False
# 3       True     False     False  False  False  False  False   False
# 4       True     False     False  False  False  False  False   False
# 5      False     False     False   True  False   True  False   False
# 6      False     False     False  False  False   True  False   False
# 7       True     False     False  False  False  False  False    True
# 8      False     False      True  False  False   True  False   False
# 9       True     False     False  False  False  False   True   False
# 10     False     False     False  False   True   True  False   False
# 11     False     False     False  False   True  False  False   False
# 12     False     False     False  False   True  False  False   False
# 13      True     False     False  False  False   True  False   False
# 14     False     False      True  False  False   True  False   False
# 15     False     False     False  False  False   True  False   False
# 16     False     False     False  False   True  False  False   False
# 17     False     False      True  False   True   True  False   False
# 18     False     False     False  False  False  False  False    True
# 19     False     False     False  False  False   True  False   False
# 20     False     False     False  False   True  False  False   False
# 21     False     False     False  False   True   True  False   False
# 22     False     False     False  False   True   True  False    True
# 23      True     False     False  False  False   True  False   False
# 24      True      True     False  False  False  False   True   False
# 25     False     False     False  False   True   True  False   False
# 26     False     False     False  False   True   True  False   False
# 27      True     False     False  False  False   True  False    True
# 28      True     False     False  False  False   True  False    True
# 29      True     False     False  False  False   True  False    True
# 30      True     False     False  False  False  False   True    True
# 31     False     False     False  False   True   True  False   False
# 32      True     False     False  False  False   True  False   False
# 33     False     False     False  False   True   True  False   False
# 34     False     False     False  False  False   True  False   False
# 35     False     False     False  False   True  False  False   False
# 36     False     False     False  False   True   True  False   False
# 37     False     False     False  False   True   True  False   False
# 38      True     False     False  False  False  False  False    True
# 39     False     False     False  False  False  False  False   False
# 40      True     False     False  False  False  False  False   False
# 41     False     False     False  False  False  False  False   False
# 42     False     False     False  False   True   True  False   False
# 43     False     False     False  False  False   True  False   False
# 44     False     False     False  False  False   True  False   False
# 45     False     False     False  False  False   True  False   False
# 46      True     False     False  False  False  False   True   False
# 47      True     False     False  False  False  False   True    True
# 48     False     False     False  False   True   True  False   False
# 49     False     False     False  False  False  False  False   False
# 50     False     False     False  False   True   True  False   False
# 51     False     False     False  False   True   True  False   False
# 52     False     False     False   True  False  False  False    True
# 53     False     False     False  False  False  False  False   False
# 54     False     False     False  False  False  False  False   False
# 55     False     False     False  False  False   True  False   False
# 56     False     False     False  False   True  False  False   False
# 57      True      True     False   True  False  False   True   False
# 58     False     False     False  False   True   True  False   False
# 59     False     False     False  False  False   True  False   False
#          ...       ...       ...    ...    ...    ...    ...     ...
#
#    Film-Noir History Horror
# 0      False   False  False ...
# 1      False   False  False ...
# 2      False   False  False ...
# 3      False   False  False ...
# 4      False   False  False ...
# 5      False   False  False ...
# 6      False   False  False ...
# 7      False   False  False ...
# 8      False    True  False ...
# 9      False   False  False ...
# 10     False   False  False ...
# 11     False   False  False ...
# 12     False   False  False ...
# 13     False    True  False ...
# 14     False    True  False ...
# 15     False   False  False ...
# 16     False   False  False ...
# 17     False   False  False ...
# 18     False    True  False ...
# 19     False   False  False ...
# 20     False   False  False ...
# 21     False   False  False ...
# 22     False   False  False ...
# 23     False   False  False ...
# 24     False   False  False ...
# 25     False   False  False ...
# 26     False   False  False ...
# 27     False   False  False ...
# 28     False   False  False ...
# 29     False   False  False ...
# 30     False   False  False ...
# 31     False   False  False ...
# 32     False   False  False ...
# 33     False   False  False ...
# 34     False    True  False ...
# 35     False   False  False ...
# 36     False   False  False ...
# 37     False   False  False ...
# 38     False   False  False ...
# 39     False   False  False ...
# 40     False   False  False ...
# 41     False   False  False ...
# 42     False   False  False ...
# 43     False   False  False ...
# 44     False   False  False ...
# 45     False   False  False ...
# 46     False   False  False ...
# 47     False   False  False ...
# 48     False   False  False ...
# 49     False   False  False ...
# 50     False   False  False ...
# 51     False   False  False ...
# 52     False   False  False ...
# 53     False   False  False ...
# 54     False   False  False ...
# 55     False   False  False ...
# 56     False   False  False ...
# 57     False   False  False ...
# 58     False   False  False ...
# 59     False   False  False ...
#          ...     ...    ...
#
# [9999 rows x 31 columns]

# %%
data.iloc[1:10,4:23]
# Out:
#     votes  runtime                            genres Action  Adult Adventure  \
# 1  490065      154                    Crime|Thriller  False  False     False
# 2  458173      139            Drama|Mystery|Thriller  False  False     False
# 3  448114      136           Action|Adventure|Sci-Fi   True  False      True
# 4  385149      148  Action|Adventure|Sci-Fi|Thriller   True  False      True
# 5  368994      142              Comedy|Drama|Romance  False  False     False
# 6  338332      122                             Drama  False  False     False
# 7  336855      162   Action|Adventure|Fantasy|Sci-Fi   True  False      True
# 8  325888      195       Biography|Drama|History|War  False  False     False
# 9  320105      124    Action|Adventure|Family|Sci-Fi   True  False      True
#
#   Animation Biography Comedy  Crime  Drama Family Fantasy Film-Noir History  \
# 1     False     False  False   True  False  False   False     False   False
# 2     False     False  False  False   True  False   False     False   False
# 3     False     False  False  False  False  False   False     False   False
# 4     False     False  False  False  False  False   False     False   False
# 5     False     False   True  False   True  False   False     False   False
# 6     False     False  False  False   True  False   False     False   False
# 7     False     False  False  False  False  False    True     False   False
# 8     False      True  False  False   True  False   False     False    True
# 9     False     False  False  False  False   True   False     False   False
#
#   Horror  Music Musical Mystery
# 1  False  False   False   False
# 2  False  False   False    True
# 3  False  False   False   False
# 4  False  False   False   False
# 5  False  False   False   False
# 6  False  False   False   False
# 7  False  False   False   False
# 8  False  False   False   False
# 9  False  False   False   False
#
# [9 rows x 19 columns]

# %% [markdown]
# ## Explore Global Properties

# %% [markdown]
# ### Exploratory Plots

# %%
#Check global to see if they make sense:
data[['score', 'runtime', 'year', 'votes']].describe()
# Out:
#              score      runtime         year          votes
# count  9999.000000  9999.000000  9999.000000    9999.000000
# mean      6.385989   103.580358  1993.471447   16605.462946
# std       1.189965    26.629310    14.830049   34564.883945
# min       1.500000     0.000000  1950.000000    1356.000000
# 25%       5.700000    93.000000  1986.000000    2334.500000
# 50%       6.600000   102.000000  1998.000000    4981.000000
# 75%       7.200000   115.000000  2005.000000   15278.500000
# max       9.200000   450.000000  2011.000000  619479.000000
#
# [8 rows x 4 columns]

# %%
# Remove any zero runtimes
print len(data[data.runtime == 0])

#probably best to flag those bad data as NAN
data.runtime[data.runtime==0] = np.nan
# Out:
# 282

# %%
data[['score', 'runtime', 'year', 'votes']].describe()
# Out:
#              score      runtime         year          votes
# count  9999.000000  9717.000000  9999.000000    9999.000000
# mean      6.385989   106.586395  1993.471447   16605.462946
# std       1.189965    20.230330    14.830049   34564.883945
# min       1.500000    45.000000  1950.000000    1356.000000
# 25%       5.700000    93.000000  1986.000000    2334.500000
# 50%       6.600000   103.000000  1998.000000    4981.000000
# 75%       7.200000   115.000000  2005.000000   15278.500000
# max       9.200000   450.000000  2011.000000  619479.000000
#
# [8 rows x 4 columns]

# %% [markdown]
# ### Exploratory Plots (histograms!)

# %%
data[data['runtime'] == 0]
# Out:
# Empty DataFrame
# Columns: [imdbID, Title, year, score, votes, runtime, genres, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Drama, Family, Fantasy, Film-Noir, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Sport, Thriller, War, Western]
# Index: []
#
# [0 rows x 31 columns]

# %%
#Exercise: do a histogram of all variables together

# %%
# more movies in recent years, but not *very* recent movies (they haven't had time to receive lots of votes yet?)
fig,ax1 = plt.subplots(1,1)
ax1.hist(data.year,bins=np.arange(1950, 2013),color='#eeeeee')
ax1.set_title('Movie Releases by Year')
ax1.set_xlabel('Release Year')

# %%
# Update the matplotlib configuration parameters:
# plt.rcParams.update({ 'font.family': 'monospace'})

# %%
fig,ax1 = plt.subplots(1,1)
ax1.hist(data.score, bins=10,color="#eeeeee")
ax1.set_title('Movie Rating Frequency')
ax1.set_xlabel("IMDB rating")

# %%
plt.hist(data.runtime.dropna(), bins=10, color='#cccccc')
plt.xlabel("Movie Run Time")
plt.ylabel("Number of Movies")
plt.title('Number of Movies per Run Times')

# %%
#hmm, more bad, recent movies. Real, or a selection bias?
plt.figure(figsize=(10,5))
plt.scatter(data.year, data.score, lw=0, alpha=.05)
plt.xlabel("Year")
plt.ylabel("Score")
plt.title("Rating over time",fontsize='15')

# %%
plt.figure(figsize=(10,5))
plt.scatter(data.votes, data.score, lw=0, alpha=.1)
plt.xlabel("Number of Votes")
plt.ylabel("IMDB Rating")
plt.title("Votes vs. Ratings",fontsize='x-large')
plt.xscale('log')

# %%
### Who are those outliers?
# Who is that movie with lots of votes but a score of betweeen 3 and 4?
# Over 70000, less than 4
data[(data.votes > 7e4) & (data.score < 4)][['Title', 'year', 'score', 'votes', 'genres']]
# Out:
#               Title  year  score  votes                       genres
# 334  Batman & Robin  1997    3.5  91875  Action|Crime|Fantasy|Sci-Fi
#
# [1 rows x 5 columns]

# %%
# The lowest rated movies
data[data.score == data.score.max()][['Title', 'year', 'score', 'votes', 'genres']]
# Out:
#                        Title  year  score   votes       genres
# 0   The Shawshank Redemption  1994    9.2  619479  Crime|Drama
# 26             The Godfather  1972    9.2  474189  Crime|Drama
#
# [2 rows x 5 columns]

# %%
# The highest rated movies
data[(data.score >7)&(data.year > 2010)][['Title', 'year', 'score', 'votes', 'genres']]
# Out:
#                                              Title  year  score  votes  \
# 460                             X-Men: First Class  2011    8.0  72810
# 609   Harry Potter and the Deathly Hallows: Part 2  2011    8.5  60422
# 624                                           Thor  2011    7.4  58330
# 733                                    Source Code  2011    7.7  53097
# 766                                      Limitless  2011    7.3  49143
# 905                          The Adjustment Bureau  2011    7.1  44011
# 940                                      Fast Five  2011    7.6  42983
# 1149                                          Paul  2011    7.2  35837
# 1301                                         Rango  2011    7.5  31795
# 1335                                       Super 8  2011    7.7  31297
# 1703                                         Hanna  2011    7.1  24357
# 1845                                           Rio  2011    7.1  22671
# 1996                            The Lincoln Lawyer  2011    7.4  20445
# 2130                               Kung Fu Panda 2  2011    7.8  19102
# 2213                                   Bridesmaids  2011    7.6  17826
# 2791                              The Tree of Life  2011    7.9  13205
# 2923                                  A Separation  2011    8.6  11954
# 3390                               Horrible Bosses  2011    7.6   9798
# 3590                             Midnight in Paris  2011    8.1   8852
# 3791                             Kill the Irishman  2011    7.1   8144
# 4060            Captain America: The First Avenger  2011    7.9   7191
# 6008                                   Delhi Belly  2011    8.2   3509
# 6395                                   Melancholia  2011    7.9   3135
# 6842                                       Win Win  2011    7.7   2756
# 6946                      Kaybedenler Kul\xfcb\xfc  2011    7.8   2680
# 7141                                     Jane Eyre  2011    7.8   2559
# 7857                       Love Likes Coincidences  2011    7.4   2136
# 8113                              Attack the Block  2011    7.4   2017
# 8173                      Zindagi Na Milegi Dobara  2011    8.3   1982
# 9049                                Eyyvah eyvah 2  2011    7.3   1651
# 9145                         No One Killed Jessica  2011    7.2   1616
# 9197                               Winnie the Pooh  2011    7.6   1598
# 9860                               The Turin Horse  2011    8.5   1389
# 9966                            Pyaar Ka Punchnama  2011    8.0   1359
#
#                                          genres
# 460               Action|Adventure|Drama|Sci-Fi
# 609             Adventure|Drama|Fantasy|Mystery
# 624                    Action|Adventure|Fantasy
# 733                     Mystery|Sci-Fi|Thriller
# 766                     Mystery|Sci-Fi|Thriller
# 905                     Romance|Sci-Fi|Thriller
# 940                 Action|Crime|Drama|Thriller
# 1149                    Adventure|Comedy|Sci-Fi
# 1301  Animation|Adventure|Comedy|Family|Western
# 1335                    Mystery|Sci-Fi|Thriller
# 1703              Action|Crime|Mystery|Thriller
# 1845  Animation|Adventure|Comedy|Family|Musical
# 1996                       Crime|Drama|Thriller
# 2130   Animation|Action|Adventure|Comedy|Family
# 2213                                     Comedy
# 2791                                      Drama
# 2923                                      Drama
# 3390                               Comedy|Crime
# 3590                     Comedy|Fantasy|Romance
# 3791                   Biography|Crime|Thriller
# 4060           Action|Adventure|Sci-Fi|Thriller
# 6008                         Comedy|Crime|Drama
# 6395                               Drama|Sci-Fi
# 6842                               Comedy|Drama
# 6946                               Comedy|Drama
# 7141                              Drama|Romance
# 7857                              Drama|Romance
# 8113                       Action|Comedy|Sci-Fi
# 8173                              Drama|Romance
# 9049                                     Comedy
# 9145                       Crime|Drama|Thriller
# 9197                           Animation|Family
# 9860                                      Drama
# 9966                       Comedy|Drama|Romance
#
# [34 rows x 5 columns]

# %%
#etc.

# %%
#temp
type(data.year)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Subset Comparisons
# Are there natural subsets we'd like to comapre?

# %%
# By Decade
# Make a separate table with the decades
decade=(data.year / 10).apply(int) * 10

tyd = data[['Title', 'year']]
tyd['decade'] = decade

tyd.head()
tyd
# Out:
#                                                 Title  year  decade
# 0                            The Shawshank Redemption  1994    1990
# 1                                        Pulp Fiction  1994    1990
# 2                                          Fight Club  1999    1990
# 3                                          The Matrix  1999    1990
# 4                                           Inception  2010    2010
# 5                                        Forrest Gump  1994    1990
# 6                                     American Beauty  1999    1990
# 7                                              Avatar  2009    2000
# 8                                    Schindler's List  1993    1990
# 9      Star Wars: Episode V - The Empire Strikes Back  1980    1980
# 10                                      Batman Begins  2005    2000
# 11                                 The Usual Suspects  1995    1990
# 12                           The Silence of the Lambs  1991    1990
# 13                                            Titanic  1997    1990
# 14                                         Braveheart  1995    1990
# 15                                    The Sixth Sense  1999    1990
# 16                                  Kill Bill: Vol. 1  2003    2000
# 17                                         Goodfellas  1990    1990
# 18                                                300  2006    2000
# 19                                       The Prestige  2006    2000
# 20                                     Reservoir Dogs  1992    1990
# 21                             Leon: The Professional  1994    1990
# 22                                     The Green Mile  1999    1990
# 23                               Inglourious Basterds  2009    2000
# 24                                          WALL\xb7E  2008    2000
# 25                                    The Dark Knight  2008    2000
# 26                                      The Godfather  1972    1970
# 27  The Lord of the Rings: The Fellowship of the Ring  2001    2000
# 28      The Lord of the Rings: The Return of the King  2003    2000
# 29              The Lord of the Rings: The Two Towers  2002    2000
# 30                 Star Wars: Episode IV - A New Hope  1977    1970
# 31                                              Se7en  1995    1990
# 32                                          Gladiator  2000    2000
# 33                                            Memento  2000    2000
# 34                                Saving Private Ryan  1998    1990
# 35                                       The Departed  2006    2000
# 36                                           Sin City  2005    2000
# 37                             The Godfather: Part II  1974    1970
# 38  Pirates of the Caribbean: The Curse of the Bla...  2003    2000
# 39                         Terminator 2: Judgment Day  1991    1990
# 40                            Raiders of the Lost Ark  1981    1980
# 41                                     V for Vendetta  2006    2000
# 42                                 American History X  1998    1990
# 43              Eternal Sunshine of the Spotless Mind  2004    2000
# 44                    One Flew Over the Cuckoo's Nest  1975    1970
# 45                                       Donnie Darko  2001    2000
# 46                                 Back to the Future  1985    1980
# 47         Star Wars: Episode VI - Return of the Jedi  1983    1980
# 48                             No Country for Old Men  2007    2000
# 49                                       Transformers  2007    2000
# 50                                 A Clockwork Orange  1971    1970
# 51                                Slumdog Millionaire  2008    2000
# 52                                          Am\xe9lie  2001    2000
# 53                                           Die Hard  1988    1980
# 54                                     The Terminator  1984    1980
# 55                                       Blade Runner  1982    1980
# 56                                            Snatch.  2000    2000
# 57                                       Finding Nemo  2003    2000
# 58                                        City of God  2002    2000
# 59                                         District 9  2009    2000
#                                                   ...   ...     ...
#
# [9999 rows x 3 columns]

# %%
# We can group the score by decade:
data.groupby(decade).score

# %%
#mean score for all movies in each decade
decade_mean = data.groupby(decade).score.mean()
print(decade_mean)
# Out:
# year
# 1950    7.244522
# 1960    7.062367
# 1970    6.842297
# 1980    6.248693
# 1990    6.199316
# 2000    6.277858
# 2010    6.344552
# Name: score, dtype: float64

# %%
plt.plot(decade_mean.index, decade_mean.values, 'o-',
        color='r', lw=1, label='Decade Average')
#plt.scatter(data.year, data.score, alpha=.04, lw=0)
plt.xlabel("Year")
plt.ylabel("Score")
plt.title("Average Score per Decade")
#plt.legend(frameon=False) # add a legend

# %%
plt.plot(decade_mean.index, decade_mean.values, 'o-',
        color='r', lw=1, label='Decade Average')
plt.scatter(data.year, data.score, alpha=.04, lw=0)
plt.xlabel("Year")
plt.ylabel("Score")
plt.title("Movie Scores over Time")
plt.legend(frameon=False) # add a legend

# %%
data[data['runtime'] == 450]
# axes.ravel flattens out an array and executes on each one.
# Out:
#          imdbID       Title  year  score  votes  runtime  \
# 6908  tt0111341  Satantango  1994    8.5   2698      450
#
#                     genres Action  Adult Adventure Animation Biography Comedy  \
# 6908  Comedy|Drama|Mystery  False  False     False     False     False   True
#
#       Crime Drama Family Fantasy Film-Noir History Horror
# 6908  False  True  False   False     False   False  False ...
#
# [1 rows x 31 columns]

# %%
# Compare across genres
# create a 4x6 grid of plots.
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12, 8), tight_layout=True)
bins = np.arange(1950, 2013, 3)

for ax, genre in zip(axes.ravel(), genresset): # Each of 24 axes gets a genre
    
     #histogram of all the movies by year -- normed, so max is highest level, 0 is lowest level -- in red
    ax.hist(data[data[genre] == 1].year, bins=bins, histtype='stepfilled', normed=True, color='r', alpha=.2, ec='none')
    
    # Histogram of movies per year for all movies -- serves as the identical background for the graph.
    ax.hist(data.year, bins=bins, histtype='stepfilled', ec='None', normed=True, zorder=0, color='#cccccc')
    
   
    ax.hist()
    
    ax.xaxis.set_ticks(np.arange(1950, 2013, 30))
    ax.set_yticks([])
    ax.annotate(genre, xy=(1955, 3e-2), fontsize=14)

    ax.set_xlabel('Year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-e57b47997f02> in <module>()
#       7
#       8      #histogram of all the movies by year -- normed, so max is highest level, 0 is lowest level -- in red
# ----> 9     ax.hist(data[data[genre] == 1].year, bins=bins, histtype='stepfilled', normed=True, color='r', alpha=.2, ec='none')
#      10
#      11     # Histogram of movies per year for all movies -- serves as the identical background for the graph.
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8247         # Massage 'x' for processing.
#    8248         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 8249         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    8250             # TODO: support masked arrays;
#    8251             x = np.asarray(x)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     489     def __getitem__(self, key):
#     490         try:
# --> 491             result = self.index.get_value(self, key)
#     492             if isinstance(result, np.ndarray):
#     493                 return self._constructor(result,index=[key]*len(result)).__finalize__(self)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1030
#    1031         try:
# -> 1032             return self._engine.get_value(s, k)
#    1033         except KeyError as e1:
#    1034             if len(self) > 0 and self.inferred_type == 'integer':
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2957)()
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2772)()
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3498)()
#
# //anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6930)()
#
# //anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6871)()
#
# KeyError: 0

# %%
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12, 8), tight_layout=True)

bins = np.arange(30, 240, 10)

for ax, genre in zip(axes.ravel(), genresset):
    ax.hist(data[data[genre] == 1].runtime, 
            bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
               
    ax.hist(data.runtime, bins=bins, normed=True,
            histtype='stepfilled', ec='none', color='#cccccc',
            zorder=0)
    
    ax.set_xticks(np.arange(30, 240, 60))
    ax.set_yticks([])
    ax.set_xlabel("Runtime [min]")
    #remove_border(ax, left=False)
    ax.annotate(genre, xy=(230, .02), ha='right', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-14fa2a87424d> in <module>()
#       5 for ax, genre in zip(axes.ravel(), genresset):
#       6     ax.hist(data[data[genre] == 1].runtime,
# ----> 7             bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
#       8
#       9     ax.hist(data.runtime, bins=bins, normed=True,
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8247         # Massage 'x' for processing.
#    8248         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 8249         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    8250             # TODO: support masked arrays;
#    8251             x = np.asarray(x)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     489     def __getitem__(self, key):
#     490         try:
# --> 491             result = self.index.get_value(self, key)
#     492             if isinstance(result, np.ndarray):
#     493                 return self._constructor(result,index=[key]*len(result)).__finalize__(self)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1030
#    1031         try:
# -> 1032             return self._engine.get_value(s, k)
#    1033         except KeyError as e1:
#    1034             if len(self) > 0 and self.inferred_type == 'integer':
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2957)()
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2772)()
#
# //anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3498)()
#
# //anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6930)()
#
# //anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6871)()
#
# KeyError: 0

# %%
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12, 8), tight_layout=True)

bins = np.arange(0, 10, .5)

for ax, genre in zip(axes.ravel(), genresset):
    ax.hist(data[data[genre] == 1].score, 
            bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
               
    ax.hist(data.score, bins=bins, normed=True,
            histtype='stepfilled', ec='none', color='#cccccc',
            zorder=0)
    
    ax.set_yticks([])
    ax.set_xlabel("Score")
    #remove_border(ax, left=False)
    ax.set_ylim(0, .4)
    ax.annotate(genre, xy=(.8, .2), ha='left', fontsize=10)
