# %% [markdown]
# #Agenda
#
# - Define the problem and the approach
# - Data basics: loading data, looking at your data, basic commands
# - <p style="color: red">Handling missing values</p>
# - Intro to scikit-learn
# - Grouping and aggregating data
# - Feature selection
# - Fitting and evaluating a model
# - Deploying your work

# %% [markdown]
# #In this workbook you will
# - Learn about imputation and what it's used for
# - Use the KNearestNeighbors algorithm to impute data
# - Come up with your own imputation strategy

# %% [markdown]
# #Imputation
# Imputation is fairly intuitive. For the missing data in our dataset, we're going to replace it with values that come from similar records in our dataset that aren't null.
# To do this we're going to use the NearestNeighbors algorithm.

# %%
import pandas as pd
import numpy as np
import pylab as pl

# %%
df = pd.read_csv("./data/credit-data-post-import.csv")

# %% [markdown]
# ##Cross Validation
# We're going to use the simplest type of cross validation. we'll simply split our data into 2 groups: training and test. we'll use the training set to calibrate our model and then use the test set to  evaluate how effective it is.

# %%
is_test = np.random.uniform(0, 1, len(df)) > 0.75
train = df[is_test==False]
test = df[is_test==True]

# %%
len(train), len(test)
# Out:
# (112551, 37449)

# %% [markdown]
# ##Be sure to calibrate the imputation with the training set

# %%
from sklearn.neighbors import KNeighborsRegressor

income_imputer = KNeighborsRegressor(n_neighbors=1)

#split our data into 2 groups; data containing nulls and data 
# not containing nulls we'll train on the latter and make
# 'predictions' on the null data to impute monthly_income
train_w_monthly_income = train[train.monthly_income.isnull()==False]
train_w_null_monthly_income = train[train.monthly_income.isnull()==True]

# %%
train_w_monthly_income.corr()
# Out:
#                                              serious_dlqin2yrs  \
# serious_dlqin2yrs                                     1.000000
# revolving_utilization_of_unsecured_lines             -0.001345
# age                                                  -0.103974
# number_of_time30-59_days_past_due_not_worse           0.126733
# debt_ratio                                           -0.003836
# monthly_income                                       -0.020708
# number_of_open_credit_lines_and_loans                -0.031600
# number_of_times90_days_late                           0.115746
# number_real_estate_loans_or_lines                    -0.007202
# number_of_time60-89_days_past_due_not_worse           0.098627
# number_of_dependents                                  0.044913
#
#                                              revolving_utilization_of_unsecured_lines  \
# serious_dlqin2yrs                                                           -0.001345
# revolving_utilization_of_unsecured_lines                                     1.000000
# age                                                                         -0.007825
# number_of_time30-59_days_past_due_not_worse                                 -0.001371
# debt_ratio                                                                   0.000184
# monthly_income                                                               0.006453
# number_of_open_credit_lines_and_loans                                       -0.011244
# number_of_times90_days_late                                                 -0.000807
# number_real_estate_loans_or_lines                                            0.004910
# number_of_time60-89_days_past_due_not_worse                                 -0.000921
# number_of_dependents                                                         0.004204
#
#                                                   age  \
# serious_dlqin2yrs                           -0.103974
# revolving_utilization_of_unsecured_lines    -0.007825
# age                                          1.000000
# number_of_time30-59_days_past_due_not_worse -0.049163
# debt_ratio                                  -0.000979
# monthly_income                               0.034150
# number_of_open_credit_lines_and_loans        0.189909
# number_of_times90_days_late                 -0.047483
# number_real_estate_loans_or_lines            0.068154
# number_of_time60-89_days_past_due_not_worse -0.043351
# number_of_dependents                        -0.207260
#
#                                              number_of_time30-59_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.126733
# revolving_utilization_of_unsecured_lines                                       -0.001371
# age                                                                            -0.049163
# number_of_time30-59_days_past_due_not_worse                                     1.000000
# debt_ratio                                                                     -0.001867
# monthly_income                                                                 -0.009944
# number_of_open_credit_lines_and_loans                                          -0.045246
# number_of_times90_days_late                                                     0.975779
# number_real_estate_loans_or_lines                                              -0.023841
# number_of_time60-89_days_past_due_not_worse                                     0.980568
# number_of_dependents                                                            0.003680
#
#                                              debt_ratio  monthly_income  \
# serious_dlqin2yrs                             -0.003836       -0.020708
# revolving_utilization_of_unsecured_lines       0.000184        0.006453
# age                                           -0.000979        0.034150
# number_of_time30-59_days_past_due_not_worse   -0.001867       -0.009944
# debt_ratio                                     1.000000       -0.027330
# monthly_income                                -0.027330        1.000000
# number_of_open_credit_lines_and_loans          0.008786        0.086257
# number_of_times90_days_late                   -0.002676       -0.011991
# number_real_estate_loans_or_lines              0.016348        0.119619
# number_of_time60-89_days_past_due_not_worse   -0.002135       -0.010532
# number_of_dependents                           0.008909        0.060228
#
#                                              number_of_open_credit_lines_and_loans  \
# serious_dlqin2yrs                                                        -0.031600
# revolving_utilization_of_unsecured_lines                                 -0.011244
# age                                                                       0.189909
# number_of_time30-59_days_past_due_not_worse                              -0.045246
# debt_ratio                                                                0.008786
# monthly_income                                                            0.086257
# number_of_open_credit_lines_and_loans                                     1.000000
# number_of_times90_days_late                                              -0.073162
# number_real_estate_loans_or_lines                                         0.427798
# number_of_time60-89_days_past_due_not_worse                              -0.062346
# number_of_dependents                                                      0.037643
#
#                                              number_of_times90_days_late  \
# serious_dlqin2yrs                                               0.115746
# revolving_utilization_of_unsecured_lines                       -0.000807
# age                                                            -0.047483
# number_of_time30-59_days_past_due_not_worse                     0.975779
# debt_ratio                                                     -0.002676
# monthly_income                                                 -0.011991
# number_of_open_credit_lines_and_loans                          -0.073162
# number_of_times90_days_late                                     1.000000
# number_real_estate_loans_or_lines                              -0.040933
# number_of_time60-89_days_past_due_not_worse                     0.989383
# number_of_dependents                                           -0.003763
#
#                                              number_real_estate_loans_or_lines  \
# serious_dlqin2yrs                                                    -0.007202
# revolving_utilization_of_unsecured_lines                              0.004910
# age                                                                   0.068154
# number_of_time30-59_days_past_due_not_worse                          -0.023841
# debt_ratio                                                            0.016348
# monthly_income                                                        0.119619
# number_of_open_credit_lines_and_loans                                 0.427798
# number_of_times90_days_late                                          -0.040933
# number_real_estate_loans_or_lines                                     1.000000
# number_of_time60-89_days_past_due_not_worse                          -0.034216
# number_of_dependents                                                  0.117538
#
#                                              number_of_time60-89_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.098627
# revolving_utilization_of_unsecured_lines                                       -0.000921
# age                                                                            -0.043351
# number_of_time30-59_days_past_due_not_worse                                     0.980568
# debt_ratio                                                                     -0.002135
# monthly_income                                                                 -0.010532
# number_of_open_credit_lines_and_loans                                          -0.062346
# number_of_times90_days_late                                                     0.989383
# number_real_estate_loans_or_lines                                              -0.034216
# number_of_time60-89_days_past_due_not_worse                                     1.000000
# number_of_dependents                                                           -0.005214
#
#                                              number_of_dependents
# serious_dlqin2yrs                                        0.044913
# revolving_utilization_of_unsecured_lines                 0.004204
# age                                                     -0.207260
# number_of_time30-59_days_past_due_not_worse              0.003680
# debt_ratio                                               0.008909
# monthly_income                                           0.060228
# number_of_open_credit_lines_and_loans                    0.037643
# number_of_times90_days_late                             -0.003763
# number_real_estate_loans_or_lines                        0.117538
# number_of_time60-89_days_past_due_not_worse             -0.005214
# number_of_dependents                                     1.000000
#
# [11 rows x 11 columns]

# %%
train_w_monthly_income.corr().ix[:,5]
# Out:
# serious_dlqin2yrs                             -0.020708
# revolving_utilization_of_unsecured_lines       0.006453
# age                                            0.034150
# number_of_time30-59_days_past_due_not_worse   -0.009944
# debt_ratio                                    -0.027330
# monthly_income                                 1.000000
# number_of_open_credit_lines_and_loans          0.086257
# number_of_times90_days_late                   -0.011991
# number_real_estate_loans_or_lines              0.119619
# number_of_time60-89_days_past_due_not_worse   -0.010532
# number_of_dependents                           0.060228
# Name: monthly_income, dtype: float64

# %%
cols = ['number_real_estate_loans_or_lines', 'number_of_open_credit_lines_and_loans']
income_imputer.fit(train_w_monthly_income[cols], train_w_monthly_income.monthly_income)

# %% [markdown]
# ##Replace the mising values

# %%
new_values = income_imputer.predict(train_w_null_monthly_income[cols])

# %%
train_w_null_monthly_income['monthly_income'] = new_values
new_values
# Out:
# array([ 3935.,  8916.,  4100., ...,  3000.,  4593.,  5400.])

# %%
#combine the data back together
train = train_w_monthly_income.append(train_w_null_monthly_income)
len(train)
# Out:
# 112551

# %%
test['monthly_income_imputed'] = income_imputer.predict(test[cols])
test.head()
# Out:
#     serious_dlqin2yrs  revolving_utilization_of_unsecured_lines  age  \
# 2                   0                                  0.658180   38
# 5                   0                                  0.213179   74
# 9                   0                                  0.189169   57
# 10                  0                                  0.644226   30
# 11                  0                                  0.018798   51
#
#     number_of_time30-59_days_past_due_not_worse  debt_ratio  monthly_income  \
# 2                                             1    0.085113            3042
# 5                                             0    0.375607            3500
# 9                                             0    0.606291           23684
# 10                                            0    0.309476            2500
# 11                                            0    0.531529            6501
#
#     number_of_open_credit_lines_and_loans  number_of_times90_days_late  \
# 2                                       2                            1
# 5                                       3                            0
# 9                                       9                            0
# 10                                      5                            0
# 11                                      7                            0
#
#     number_real_estate_loans_or_lines  \
# 2                                   0
# 5                                   1
# 9                                   4
# 10                                  0
# 11                                  2
#
#     number_of_time60-89_days_past_due_not_worse  number_of_dependents  \
# 2                                             0                     0
# 5                                             0                     1
# 9                                             0                     2
# 10                                            0                     0
# 11                                            0                     2
#
#     monthly_income_imputed
# 2                     8916
# 5                     2100
# 9                      900
# 10                    3000
# 11                    7117
#
# [5 rows x 12 columns]

# %%
test['monthly_income'] = np.where(test.monthly_income.isnull(), test.monthly_income_imputed,
                                  test.monthly_income)

# %%
print pd.value_counts(train.monthly_income.isnull())
print pd.value_counts(test.monthly_income.isnull())
# Out:
# False    112551
# dtype: int64
# False    37449
# dtype: int64

# %%
train.to_csv("./data/credit-data-trainingset.csv", index=False)
test.to_csv("./data/credit-data-testset.csv", index=False)

# %% [markdown]
# ##Trying your own imputation strategy
# Partner with the person next to you and think of other ways you might be able to impute missing valus for the `monthly_income` column.
#
# Things to consider:
#
# - Are `number_of_open_credit_lines_and_loans` and `number_real_estate_loans_or_lines` the best predictors?
# - What are some other methods you could use for replacing nulls?
# - What about handling outlying values? Should a montly income of $3MM be treated as missing?
# - Check out the [scikit-learn docs](http://scikit-learn.org/stable/auto_examples/imputation.html) for more examples
# - How might you evaluate the effectiveness of your imputation?

# %% [markdown]
# ##We just did the following
#
# - Split our data into a training set for building our model and a test set for evaluating its performance
# - Used KNearestNeighbors to fill in missing values for `monthly_income`
